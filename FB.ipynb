# %%
import pandas as pd

# %%
df = pd.read_excel("FB_Q.xlsx")

# %%
df.head(20)
# Out:
#     Data provided by SimFin                                       Unnamed: 1  \
# 0                       NaN                                              NaN
# 1   Profit & Loss statement                                              NaN
# 2                       NaN                                   in million USD
# 3                       NaN                                          Revenue
# 4                       NaN                                  Cost of revenue
# 5                       NaN                                     Gross Profit
# 6                       NaN                               Operating Expenses
# 7                       NaN                          Operating Income (Loss)
# 8                       NaN                      Non-Operating Income (Loss)
# 9                       NaN                             Pretax Income (Loss)
# 10                      NaN                Income Tax (Expense) Benefit, net
# ...

# %%
start_PL = df.loc[df["Data provided by SimFin"]== "Profit & Loss statement"].index[0]
start_BS = df.loc[df["Data provided by SimFin"]== "Balance Sheet"].index[0]
start_CF = df.loc[df["Data provided by SimFin"]== "Cash Flow statement"].index[0]
print(start_PL)
print(start_BS)
print(start_CF)
# Out:
# 1
# 15
# 40

# %%
df_PL = df.iloc[start_PL:start_BS-1,1:]
df_PL = df_PL[1:]
df_PL
# Out:
#                                      Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 2                                in million USD     Q1 '18     Q2 '18
# 3                                       Revenue      11966      13231
# 4                               Cost of revenue      -1927      -2214
# 5                                  Gross Profit      10039      11017
# 6                            Operating Expenses      -4590      -5154
# 7                       Operating Income (Loss)       5449       5863
# 8                   Non-Operating Income (Loss)        161          5
# 9                          Pretax Income (Loss)       5610       5868
# 10            Income Tax (Expense) Benefit, net       -622       -762
# 11                                   Net Income       4988       5106
# 12                            Other Adjustments         -1          0
# 13  Net Income Available to Common Shareholders       4987       5106
#
# ...

# %%
df_PL.columns = df_PL.iloc[0]
df_PL.columns
df_PL = df_PL[1:]
df_PL
# Out:
# 2                                in million USD Q1 '18 Q2 '18 Q3 '18 Q4 '18  \
# 3                                       Revenue  11966  13231  13727  16914
# 4                               Cost of revenue  -1927  -2214  -2418  -2796
# 5                                  Gross Profit  10039  11017  11309  14118
# 6                            Operating Expenses  -4590  -5154  -5528  -6298
# 7                       Operating Income (Loss)   5449   5863   5781   7820
# 8                   Non-Operating Income (Loss)    161      5    131    151
# 9                          Pretax Income (Loss)   5610   5868   5912   7971
# 10            Income Tax (Expense) Benefit, net   -622   -762   -775  -1090
# 11                                   Net Income   4988   5106   5137   6881
# 12                            Other Adjustments     -1      0      0      0
# 13  Net Income Available to Common Shareholders   4987   5106   5137   6881
#
# 2  Q1 '19 Q2 '19 Q3 '19 Q4 '19 Q1 '20 Q2 '20
# ...

# %%
df_PL.set_index("in million USD", inplace=True)
df_PL
# Out:
# 2                                           Q1 '18 Q2 '18 Q3 '18 Q4 '18  \
# in million USD
# Revenue                                      11966  13231  13727  16914
# Cost of revenue                              -1927  -2214  -2418  -2796
# Gross Profit                                 10039  11017  11309  14118
# Operating Expenses                           -4590  -5154  -5528  -6298
# Operating Income (Loss)                       5449   5863   5781   7820
# Non-Operating Income (Loss)                    161      5    131    151
# Pretax Income (Loss)                          5610   5868   5912   7971
# Income Tax (Expense) Benefit, net             -622   -762   -775  -1090
# Net Income                                    4988   5106   5137   6881
# Other Adjustments                               -1      0      0      0
# Net Income Available to Common Shareholders   4987   5106   5137   6881
#
# 2                                           Q1 '19 Q2 '19 Q3 '19 Q4 '19  \
# ...

# %%
df_PL.fillna(0, inplace=True)
df_PL
# Out:
# c:\python\python38\lib\site-packages\pandas\core\frame.py:4147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# 2                                            Q1 '18  Q2 '18  Q3 '18  Q4 '18  \
# in million USD
# Revenue                                       11966   13231   13727   16914
# Cost of revenue                               -1927   -2214   -2418   -2796
# Gross Profit                                  10039   11017   11309   14118
# Operating Expenses                            -4590   -5154   -5528   -6298
# Operating Income (Loss)                        5449    5863    5781    7820
# Non-Operating Income (Loss)                     161       5     131     151
# Pretax Income (Loss)                           5610    5868    5912    7971
# ...

# %%
df_BS = df.iloc[start_BS:start_CF-1,1:]
df_BS = df_BS[1:]
df_BS
# Out:
#                                          Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 16                                   in million USD     Q1 '18     Q2 '18
# 17                                           Assets        NaN        NaN
# 18  Cash, Cash Equivalents & Short Term Investments      43956      42309
# 19                      Accounts & Notes Receivable       5115       5590
# 20                          Other Short Term Assets       1341       1934
# 21                             Total Current Assets      50412      49833
# 22                 Property, Plant & Equipment, Net      16211      18357
# 23                           Other Long Term Assets      22322      22101
# 24                          Total Noncurrent Assets      38533      40458
# 25                                     Total Assets      88945      90291
# 26                                      Liabilities        NaN        NaN
# 27                              Payables & Accruals       4992       4579
# ...

# %%
df_BS.columns = df_BS.iloc[0]
df_BS.columns
# Out:
# Index(['in million USD', 'Q1 '18', 'Q2 '18', 'Q3 '18', 'Q4 '18', 'Q1 '19',
#        'Q2 '19', 'Q3 '19', 'Q4 '19', 'Q1 '20', 'Q2 '20'],
#       dtype='object', name=16)

# %%
df_BS
# Out:
# 16                                   in million USD  Q1 '18  Q2 '18  Q3 '18  \
# 16                                   in million USD  Q1 '18  Q2 '18  Q3 '18
# 17                                           Assets     NaN     NaN     NaN
# 18  Cash, Cash Equivalents & Short Term Investments   43956   42309   41206
# 19                      Accounts & Notes Receivable    5115    5590    6058
# 20                          Other Short Term Assets    1341    1934    1883
# 21                             Total Current Assets   50412   49833   49147
# 22                 Property, Plant & Equipment, Net   16211   18357   21112
# 23                           Other Long Term Assets   22322   22101   22193
# 24                          Total Noncurrent Assets   38533   40458   43305
# 25                                     Total Assets   88945   90291   92452
# 26                                      Liabilities     NaN     NaN     NaN
# ...

# %%
df_BS = df_BS[1:]

# %%
df_BS
# Out:
# 16                                   in million USD Q1 '18 Q2 '18 Q3 '18  \
# 17                                           Assets    NaN    NaN    NaN
# 18  Cash, Cash Equivalents & Short Term Investments  43956  42309  41206
# 19                      Accounts & Notes Receivable   5115   5590   6058
# 20                          Other Short Term Assets   1341   1934   1883
# 21                             Total Current Assets  50412  49833  49147
# 22                 Property, Plant & Equipment, Net  16211  18357  21112
# 23                           Other Long Term Assets  22322  22101  22193
# 24                          Total Noncurrent Assets  38533  40458  43305
# 25                                     Total Assets  88945  90291  92452
# 26                                      Liabilities    NaN    NaN    NaN
# 27                              Payables & Accruals   4992   4579   5347
# 28                     Other Short Term Liabilities     94     91    115
# ...

# %%
df_BS.fillna(0,inplace=True)
df_BS.set_index("in million USD", inplace=True)
df_BS
# Out:
# c:\python\python38\lib\site-packages\pandas\core\frame.py:4147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# 16                                               Q1 '18  Q2 '18  Q3 '18  \
# in million USD
# Assets                                                0       0       0
# Cash, Cash Equivalents & Short Term Investments   43956   42309   41206
# Accounts & Notes Receivable                        5115    5590    6058
# Other Short Term Assets                            1341    1934    1883
# Total Current Assets                              50412   49833   49147
# Property, Plant & Equipment, Net                  16211   18357   21112
# Other Long Term Assets                            22322   22101   22193
# ...

# %%
df_BS = df_BS[1:]
df_BS
# Out:
# 16                                               Q1 '18  Q2 '18  Q3 '18  \
# in million USD
# Cash, Cash Equivalents & Short Term Investments   43956   42309   41206
# Accounts & Notes Receivable                        5115    5590    6058
# Other Short Term Assets                            1341    1934    1883
# Total Current Assets                              50412   49833   49147
# Property, Plant & Equipment, Net                  16211   18357   21112
# Other Long Term Assets                            22322   22101   22193
# Total Noncurrent Assets                           38533   40458   43305
# Total Assets                                      88945   90291   92452
# Liabilities                                           0       0       0
# Payables & Accruals                                4992    4579    5347
# Other Short Term Liabilities                         94      91     115
# Total Current Liabilities                          5086    4670    5462
# ...

# %%
df_CF = df.iloc[start_CF:,1:]
df_CF = df_CF.iloc[1:]
df_CF
# Out:
#                                    Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 41                             in million USD     Q1 '18     Q2 '18
# 42                   Net Income/Starting Line       4988       5105
# 43                Depreciation & Amortization        949       1034
# 44                             Non-Cash Items        916       1297
# 45                  Change in Working Capital       1007      -1138
# 46             Cash from Operating Activities       7860       6298
# 47       Change in Fixed Assets & Intangibles      -2812      -3460
# 48         Net Change in Long Term Investment       1575       1092
# 49  Net Cash From Acquisitions & Divestitures        NaN        -65
# 50                 Other Investing Activities        -50         49
# 51             Cash from Investing Activities      -1287      -2384
# 52              Cash From (Repayment of) Debt          0        NaN
# 53           Cash From (Repurchase of) Equity      -1774      -3349
# ...

# %%
df_CF.columns = df_CF.iloc[0]
df_CF.columns
# Out:
# Index(['in million USD', 'Q1 '18', 'Q2 '18', 'Q3 '18', 'Q4 '18', 'Q1 '19',
#        'Q2 '19', 'Q3 '19', 'Q4 '19', 'Q1 '20', 'Q2 '20'],
#       dtype='object', name=41)

# %%
df_CF
# Out:
# 41                             in million USD  Q1 '18  Q2 '18  Q3 '18  Q4 '18  \
# 41                             in million USD  Q1 '18  Q2 '18  Q3 '18  Q4 '18
# 42                   Net Income/Starting Line    4988    5105    5137    6882
# 43                Depreciation & Amortization     949    1034    1107    1225
# 44                             Non-Cash Items     916    1297    1069    1092
# 45                  Change in Working Capital    1007   -1138     185   -1581
# 46             Cash from Operating Activities    7860    6298    7498    7618
# 47       Change in Fixed Assets & Intangibles   -2812   -3460   -3342   -4301
# 48         Net Change in Long Term Investment    1575    1092    -830     637
# 49  Net Cash From Acquisitions & Divestitures     NaN     -65     -72       0
# 50                 Other Investing Activities     -50      49      -3     -21
# 51             Cash from Investing Activities   -1287   -2384   -4247   -3685
# ...

# %%
df_CF.fillna(0,inplace=True)

# %%
df_CF
# Out:
# 41                             in million USD  Q1 '18  Q2 '18  Q3 '18  Q4 '18  \
# 41                             in million USD  Q1 '18  Q2 '18  Q3 '18  Q4 '18
# 42                   Net Income/Starting Line    4988    5105    5137    6882
# 43                Depreciation & Amortization     949    1034    1107    1225
# 44                             Non-Cash Items     916    1297    1069    1092
# 45                  Change in Working Capital    1007   -1138     185   -1581
# 46             Cash from Operating Activities    7860    6298    7498    7618
# 47       Change in Fixed Assets & Intangibles   -2812   -3460   -3342   -4301
# 48         Net Change in Long Term Investment    1575    1092    -830     637
# 49  Net Cash From Acquisitions & Divestitures       0     -65     -72       0
# 50                 Other Investing Activities     -50      49      -3     -21
# 51             Cash from Investing Activities   -1287   -2384   -4247   -3685
# ...

# %%
df_CF = df_CF[1:]
df_CF
# Out:
# 41                             in million USD Q1 '18 Q2 '18 Q3 '18 Q4 '18  \
# 42                   Net Income/Starting Line   4988   5105   5137   6882
# 43                Depreciation & Amortization    949   1034   1107   1225
# 44                             Non-Cash Items    916   1297   1069   1092
# 45                  Change in Working Capital   1007  -1138    185  -1581
# 46             Cash from Operating Activities   7860   6298   7498   7618
# 47       Change in Fixed Assets & Intangibles  -2812  -3460  -3342  -4301
# 48         Net Change in Long Term Investment   1575   1092   -830    637
# 49  Net Cash From Acquisitions & Divestitures      0    -65    -72      0
# 50                 Other Investing Activities    -50     49     -3    -21
# 51             Cash from Investing Activities  -1287  -2384  -4247  -3685
# 52              Cash From (Repayment of) Debt      0      0      0    500
# 53           Cash From (Repurchase of) Equity  -1774  -3349  -4256  -3500
# ...

# %%
df_CF.set_index("in million USD", inplace=True)
df_CF
# Out:
# 41                                        Q1 '18 Q2 '18 Q3 '18 Q4 '18 Q1 '19  \
# in million USD
# Net Income/Starting Line                    4988   5105   5137   6882   2429
# Depreciation & Amortization                  949   1034   1107   1225   1355
# Non-Cash Items                               916   1297   1069   1092   1199
# Change in Working Capital                   1007  -1138    185  -1581   4325
# Cash from Operating Activities              7860   6298   7498   7618   9308
# Change in Fixed Assets & Intangibles       -2812  -3460  -3342  -4301  -3837
# Net Change in Long Term Investment          1575   1092   -830    637  -2881
# Net Cash From Acquisitions & Divestitures      0    -65    -72      0      0
# Other Investing Activities                   -50     49     -3    -21    -50
# Cash from Investing Activities             -1287  -2384  -4247  -3685  -6768
# Cash From (Repayment of) Debt                  0      0      0    500   -177
# ...

# %%
df_PL.to_pickle("FB_PL.pkl")
df_BS.to_pickle("FBBS.pkl")
df_CF.to_pickle("FB_CF.pkl")

# %%
# %matplotlib inline
df_PL.plot()
# Out:
# c:\python\python38\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='in million USD'>

# %%
df_PL = df_PL.T
df_PL
# Out:
# in million USD  Revenue  Cost of revenue  Gross Profit  Operating Expenses  \
# 2
# Q1 '18            11966            -1927         10039               -4590
# Q2 '18            13231            -2214         11017               -5154
# Q3 '18            13727            -2418         11309               -5528
# Q4 '18            16914            -2796         14118               -6298
# Q1 '19            15077            -2816         12261               -8944
# Q2 '19            16886            -3307         13579               -8953
# Q3 '19            17652            -3155         14497               -7312
# Q4 '19            21082            -3492         17590               -8732
# Q1 '20            17737            -3459         14278               -8385
# Q2 '20            18687            -3829         14858               -8895
#
# in million USD  Operating Income (Loss)  Non-Operating Income (Loss)  \
# 2
# ...

# %%
df_PL.plot()
# Out:
# c:\python\python38\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='2'>

# %%
assets = '''
Cash, Cash Equivalents & Short Term Investments
Accounts & Notes Receivable
Inventories
Property, Plant & Equipment, Net
Other Long Term Assets
'''

column_assets = [x for x in assets.strip().split("\n")]
column_assets
# Out:
# ['Cash, Cash Equivalents & Short Term Investments',
#  'Accounts & Notes Receivable',
#  'Inventories',
#  'Property, Plant & Equipment, Net',
#  'Other Long Term Assets']

# %%
df_BS = df_BS.T
df_BS
# Out:
# in million USD  Cash, Cash Equivalents & Short Term Investments  \
# 16
# Q1 '18                                                    43956
# Q2 '18                                                    42309
# Q3 '18                                                    41206
# Q4 '18                                                    41114
# Q1 '19                                                    45243
# Q2 '19                                                    48596
# Q3 '19                                                    52269
# Q4 '19                                                    54855
# Q1 '20                                                    60289
# Q2 '20                                                    58240
#
# in million USD  Accounts & Notes Receivable  Other Short Term Assets  \
# 16
# Q1 '18                                 5115                     1341
# Q2 '18                                 5590                     1934
# ...

# %%
df_CF = df_CF.T

# %%
df_CF
# Out:
# in million USD Net Income/Starting Line Depreciation & Amortization  \
# 41
# Q1 '18                             4988                         949
# Q2 '18                             5105                        1034
# Q3 '18                             5137                        1107
# Q4 '18                             6882                        1225
# Q1 '19                             2429                        1355
# Q2 '19                             2616                        1502
# Q3 '19                             6091                        1416
# Q4 '19                             7349                        1468
# Q1 '20                             4902                        1597
# Q2 '20                             5179                        1704
#
# in million USD Non-Cash Items Change in Working Capital  \
# 41
# Q1 '18                    916                      1007
# Q2 '18                   1297                     -1138
# ...

# %%
df_BS[column_assets].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-c84532f79294> in <module>
# ----> 1 df_BS[column_assets].plot()
#
# c:\python\python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# c:\python\python38\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ...
